# %%
# Customer Segmentation Project

# %%
#Import neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Display all columns 
pd.set_option('display.max_columns',None)

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the Dataset
df = pd.read_excel(r"C:\Users\saiki\Desktop\Project1A\Customer_Segmention\Customer_Segmentation_Raw.xlsx")

# %%
df.head()
# Out:
#   Customer_ID   Age Gender  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0       C0001  58.0   Male        23278.0            95.0                 9.0
# 1       C0002  32.0   Male            NaN            14.0                22.0
# 2       C0003  23.0  Other        75302.0             5.0                 1.0
# 3       C0004  31.0   Male        86237.0            78.0                 1.0
# 4       C0005  30.0  Other       105181.0            90.0                18.0
#
#    Total_Purchase_Amount
# 0                19854.0
# 1               102674.0
# 2                  967.0
# 3                 4797.0
# 4                65448.0

# %%
df.head(10)
# Out:
#   Customer_ID   Age  Gender  Annual_Income  Spending_Score  \
# 0       C0001  58.0    Male        23278.0            95.0
# 1       C0002  32.0    Male            NaN            14.0
# 2       C0003  23.0   Other        75302.0             5.0
# 3       C0004  31.0    Male        86237.0            78.0
# 4       C0005  30.0   Other       105181.0            90.0
# 5       C0006  32.0  Female        97236.0            36.0
# 6       C0007   NaN    Male       111506.0            55.0
# 7       C0008  27.0    Male       145463.0            98.0
# 8       C0009  23.0  Female        32676.0            46.0
# 9       C0010   NaN  Female       125791.0             6.0
#
#    Purchase_Frequency  Total_Purchase_Amount
# 0                 9.0                19854.0
# 1                22.0               102674.0
# 2                 1.0                  967.0
# 3                 1.0                 4797.0
# 4                18.0                65448.0
# ...

# %%
df.tail(10)
# Out:
#     Customer_ID   Age  Gender  Annual_Income  Spending_Score  \
# 740       C0023  27.0  Female        38301.0            32.0
# 741       C0067  33.0  Female        71876.0            17.0
# 742       C0203  51.0  Female       101609.0            97.0
# 743       C0662  54.0  Female        89767.0            36.0
# 744       C0455  27.0   Other       137064.0            66.0
# 745       C0132  47.0    Male       148545.0            80.0
# 746       C0095  56.0  Female        65309.0            94.0
# 747       C0340  68.0   Other       104843.0            43.0
# 748       C0126  31.0  Female        71049.0            99.0
# 749       C0044  55.0    Male        20942.0            10.0
#
#      Purchase_Frequency  Total_Purchase_Amount
# 740                24.0               115152.0
# 741                22.0                58454.0
# 742                16.0                61136.0
# 743                20.0                92260.0
# 744                 5.0                14430.0
# ...

# %%
print("Rows and Columns:",df.shape)
# Out:
# Rows and Columns: (750, 7)

# %%
print(df.columns)
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Annual_Income', 'Spending_Score',
#        'Purchase_Frequency', 'Total_Purchase_Amount'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Customer_ID               object
# Age                      float64
# Gender                    object
# Annual_Income            float64
# Spending_Score           float64
# Purchase_Frequency       float64
# Total_Purchase_Amount    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            750 non-null    object
#  1   Age                    734 non-null    float64
#  2   Gender                 734 non-null    object
#  3   Annual_Income          741 non-null    float64
#  4   Spending_Score         740 non-null    float64
#  5   Purchase_Frequency     744 non-null    float64
#  6   Total_Purchase_Amount  744 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 41.1+ KB

# %%
df.describe()
# Out:
#               Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# count  734.000000     741.000000      740.000000          744.000000
# mean    44.773842   86223.948718       52.939189           15.495968
# std     15.579767   36713.744548       29.126347            8.596690
# min     18.000000   20800.000000        1.000000            1.000000
# 25%     31.000000   56368.000000       29.000000            8.000000
# 50%     46.000000   86402.000000       53.500000           15.500000
# 75%     58.000000  117472.000000       80.000000           23.000000
# max     70.000000  149853.000000      100.000000           30.000000
#
#        Total_Purchase_Amount
# count             744.000000
# mean            41061.071237
# std             32935.195542
# min               832.000000
# 25%             14537.250000
# 50%             32296.000000
# 75%             61161.250000
# max            147960.000000

# %%
df.describe(include='all')
# Out:
#        Customer_ID         Age Gender  Annual_Income  Spending_Score  \
# count          750  734.000000    734     741.000000      740.000000
# unique         730         NaN      3            NaN             NaN
# top          C0597         NaN  Other            NaN             NaN
# freq             2         NaN    247            NaN             NaN
# mean           NaN   44.773842    NaN   86223.948718       52.939189
# std            NaN   15.579767    NaN   36713.744548       29.126347
# min            NaN   18.000000    NaN   20800.000000        1.000000
# 25%            NaN   31.000000    NaN   56368.000000       29.000000
# 50%            NaN   46.000000    NaN   86402.000000       53.500000
# 75%            NaN   58.000000    NaN  117472.000000       80.000000
# max            NaN   70.000000    NaN  149853.000000      100.000000
#
#         Purchase_Frequency  Total_Purchase_Amount
# count           744.000000             744.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Age                      16
# Gender                   16
# Annual_Income             9
# Spending_Score           10
# Purchase_Frequency        6
# Total_Purchase_Amount     6
# dtype: int64

# %%
print("Total Missing Values:",df.isnull().sum().sum())
# Out:
# Total Missing Values: 63

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing Count':df.isnull().sum(),
    'Missing Percentage':missing_percentage
})

missing_df
# Out:
#                        Missing Count  Missing Percentage
# Customer_ID                        0            0.000000
# Age                               16            2.133333
# Gender                            16            2.133333
# Annual_Income                      9            1.200000
# Spending_Score                    10            1.333333
# Purchase_Frequency                 6            0.800000
# Total_Purchase_Amount              6            0.800000

# %%
print("Duplicated Rows:",df.duplicated().sum())
# Out:
# Duplicated Rows: 20

# %%
df=df.drop_duplicates()

# %%
print("Duplicated Rows After Removal:",df.duplicated().sum())
# Out:
# Duplicated Rows After Removal: 0

# %%
print(df.shape)
# Out:
# (730, 7)

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Age                      15
# Gender                   15
# Annual_Income             9
# Spending_Score            9
# Purchase_Frequency        6
# Total_Purchase_Amount     6
# dtype: int64

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_columns:
    df[col].fillna(df[col].median(), inplace=True)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Gender                   0
# Annual_Income            0
# Spending_Score           0
# Purchase_Frequency       0
# Total_Purchase_Amount    0
# dtype: int64

# %%
df.nunique()
# Out:
# Customer_ID              730
# Age                       53
# Gender                     3
# Annual_Income            721
# Spending_Score           100
# Purchase_Frequency        30
# Total_Purchase_Amount    717
# dtype: int64

# %%
df.dtypes
# Out:
# Customer_ID               object
# Age                      float64
# Gender                    object
# Annual_Income            float64
# Spending_Score           float64
# Purchase_Frequency       float64
# Total_Purchase_Amount    float64
# dtype: object

# %%
df['Customer_ID'] = df['Customer_ID'].astype(str)

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
df['Age'] = df['Age'].astype(int)

# %%
df['Annual_Income'] = df['Annual_Income'].astype(float)

# %%
df['Spending_Score'] = df['Spending_Score'].astype(float)

# %%
df['Purchase_Frequency'] = df['Purchase_Frequency'].astype(int)

# %%
df['Total_Purchase_Amount'] = df['Total_Purchase_Amount'].astype(float)

# %%
df.dtypes
# Out:
# Customer_ID                object
# Age                         int64
# Gender                   category
# Annual_Income             float64
# Spending_Score            float64
# Purchase_Frequency          int64
# Total_Purchase_Amount     float64
# dtype: object

# %%
df.to_csv("Customer_data_cleaned.csv",index=False)

# %%
features = df[['Age',
               'Annual_Income',
               'Spending_Score',
               'Purchase_Frequency',
               'Total_Purchase_Amount']]

features.head()
# Out:
#    Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0   58        23278.0            95.0                   9
# 1   32        86249.0            14.0                  22
# 2   23        75302.0             5.0                   1
# 3   31        86237.0            78.0                   1
# 4   30       105181.0            90.0                  18
#
#    Total_Purchase_Amount
# 0                19854.0
# 1               102674.0
# 2                  967.0
# 3                 4797.0
# 4                65448.0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_features = scaler.fit_transform(features)

scaled_df = pd.DataFrame(
    scaled_features,
    columns=features.columns
)

scaled_df.head()
# Out:
#         Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0  0.865089      -1.721914        1.455134           -0.753109
# 1 -0.826760       0.009386       -1.355045            0.763014
# 2 -1.412399      -0.291586       -1.667288           -1.686107
# 3 -0.891831       0.009056        0.865343           -1.686107
# 4 -0.956902       0.529896        1.281666            0.296515
#
#    Total_Purchase_Amount
# 0              -0.645411
# 1               1.877456
# 2              -1.220748
# 3              -1.104078
# 4               0.743476

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(df["Age"], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Annual_Income"], bins=20)
plt.title("Annual Income Distribution")
plt.xlabel("Annual Income")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Spending_Score"], bins=20)
plt.title("Spending Score Distribution")
plt.xlabel("Spending Score")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Purchase_Frequency"], bins=20)
plt.title("Purchase Frequency Distribution")
plt.xlabel("Purchase Frequency")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Total_Purchase_Amount"], bins=20)
plt.title("Total Purchase Amount Distribution")
plt.xlabel("Total Purchase Amount")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Age"])
plt.title("Box Plot - Age")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Annual_Income"])
plt.title("Box Plot - Annual Income")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Spending_Score"])
plt.title("Box Plot - Spending Score")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Purchase_Frequency"])
plt.title("Box Plot - Purchase Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Total_Purchase_Amount"])
plt.title("Box Plot - Total Purchase Amount")
plt.show()

# %%
correlation = df[[
    "Age",
    "Annual_Income",
    "Spending_Score",
    "Purchase_Frequency",
    "Total_Purchase_Amount"
]].corr()

correlation
# Out:
#                             Age  Annual_Income  Spending_Score  \
# Age                    1.000000       0.016706       -0.027838
# Annual_Income          0.016706       1.000000       -0.002053
# Spending_Score        -0.027838      -0.002053        1.000000
# Purchase_Frequency    -0.034167      -0.022168        0.042938
# Total_Purchase_Amount -0.022667      -0.056175       -0.015211
#
#                        Purchase_Frequency  Total_Purchase_Amount
# Age                             -0.034167              -0.022667
# Annual_Income                   -0.022168              -0.056175
# Spending_Score                   0.042938              -0.015211
# Purchase_Frequency               1.000000               0.662497
# Total_Purchase_Amount            0.662497               1.000000

# %%
plt.figure(figsize=(8,6))

plt.imshow(correlation, cmap="coolwarm", interpolation="nearest")

plt.colorbar()

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=45
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df["Annual_Income"],
    df["Spending_Score"]
)

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Annual Income vs Spending Score")

plt.show()

# %%
df.groupby("Gender")[[
    "Age",
    "Annual_Income",
    "Spending_Score",
    "Purchase_Frequency",
    "Total_Purchase_Amount"
]].mean()
# Out:
#               Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# Gender
# Female  44.195745   81345.412766       53.059574           15.978723
# Male    44.201681   90470.802521       51.647059           15.046218
# Other   45.638132   85853.400778       54.361868           15.361868
#
#         Total_Purchase_Amount
# Gender
# Female           44227.914894
# Male             37992.163866
# Other            40951.396887

# %%
print("""
EDA Summary

1. Dataset structure and dimensions were examined.
2. Missing values and duplicate records were checked.
3. Statistical summaries were generated.
4. Histograms showed the distribution of numerical features.
5. Box plots were used to identify potential outliers.
6. Correlation analysis highlighted relationships among variables.
7. Gender-wise averages provided additional customer insights.
""")
# Out:
# EDA Summary
#
# 1. Dataset structure and dimensions were examined.
# 2. Missing values and duplicate records were checked.
# 3. Statistical summaries were generated.
# 4. Histograms showed the distribution of numerical features.
# 5. Box plots were used to identify potential outliers.
# 6. Correlation analysis highlighted relationships among variables.
# 7. Gender-wise averages provided additional customer insights.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for i in range(1,11):
    kmeans = KMeans(
        n_clusters=i,
        random_state=42,
        n_init=10
    )

    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10
)

clusters = kmeans.fit_predict(scaled_df)

# %%
df["Cluster"] = clusters

df.head()
# Out:
#   Customer_ID  Age Gender  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0       C0001   58   Male        23278.0            95.0                   9
# 1       C0002   32   Male        86249.0            14.0                  22
# 2       C0003   23  Other        75302.0             5.0                   1
# 3       C0004   31   Male        86237.0            78.0                   1
# 4       C0005   30  Other       105181.0            90.0                  18
#
#    Total_Purchase_Amount  Cluster
# 0                19854.0        0
# 1               102674.0        3
# 2                  967.0        0
# 3                 4797.0        0
# 4                65448.0        1

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Annual_Income"],
    df["Spending_Score"],
    c=df["Cluster"]
)

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segments")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Purchase_Frequency"],
    df["Total_Purchase_Amount"],
    c=df["Cluster"]
)

plt.xlabel("Purchase Frequency")
plt.ylabel("Total Purchase Amount")
plt.title("Clusters based on Purchases")

plt.show()

# %%
cluster_summary = df.groupby("Cluster").mean(numeric_only=True)

cluster_summary
# Out:
#                Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# Cluster
# 0        43.707447   50814.920213       51.914894            9.175532
# 1        28.352941  101315.452941       57.676471           18.711765
# 2        54.663158  117420.063158       48.352632           10.478947
# 3        50.615385   74867.598901       54.835165           24.104396
#
#          Total_Purchase_Amount
# Cluster
# 0                 21701.127660
# 1                 39975.841176
# 2                 22179.184211
# 3                 81705.791209

# %%
cluster_summary = df.groupby("Cluster").agg({
    "Age":"mean",
    "Annual_Income":"mean",
    "Spending_Score":"mean",
    "Purchase_Frequency":"mean",
    "Total_Purchase_Amount":"mean"
})

cluster_summary
# Out:
#                Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# Cluster
# 0        43.707447   50814.920213       51.914894            9.175532
# 1        28.352941  101315.452941       57.676471           18.711765
# 2        54.663158  117420.063158       48.352632           10.478947
# 3        50.615385   74867.598901       54.835165           24.104396
#
#          Total_Purchase_Amount
# Cluster
# 0                 21701.127660
# 1                 39975.841176
# 2                 22179.184211
# 3                 81705.791209

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 2    190
# 0    188
# 3    182
# 1    170
# Name: count, dtype: int64

# %%
df["Cluster"].value_counts().plot(
    kind="bar",
    figsize=(6,5)
)

plt.xlabel("Cluster")
plt.ylabel("Number of Customers")
plt.title("Customers per Cluster")

plt.show()

# %%
df.to_csv(
    "customer_segments.csv",
    index=False
)

print("Segmented dataset saved successfully.")
# Out:
# Segmented dataset saved successfully.

# %%
for cluster in sorted(df["Cluster"].unique()):

    print("\n")
    print("Cluster:", cluster)

    subset = df[df["Cluster"] == cluster]

    print("Average Age:",
          round(subset["Age"].mean(),2))

    print("Average Income:",
          round(subset["Annual_Income"].mean(),2))

    print("Average Spending Score:",
          round(subset["Spending_Score"].mean(),2))

    print("Average Purchase Frequency:",
          round(subset["Purchase_Frequency"].mean(),2))

    print("Average Purchase Amount:",
          round(subset["Total_Purchase_Amount"].mean(),2))
# Out:
# Cluster: 0
# Average Age: 43.71
# Average Income: 50814.92
# Average Spending Score: 51.91
# Average Purchase Frequency: 9.18
# Average Purchase Amount: 21701.13
#
#
# Cluster: 1
# Average Age: 28.35
# Average Income: 101315.45
# Average Spending Score: 57.68
# Average Purchase Frequency: 18.71
# Average Purchase Amount: 39975.84
#
#
# Cluster: 2
# Average Age: 54.66
# Average Income: 117420.06
# Average Spending Score: 48.35
# Average Purchase Frequency: 10.48
# Average Purchase Amount: 22179.18
#
#
# Cluster: 3
# Average Age: 50.62
# Average Income: 74867.6
# Average Spending Score: 54.84
# Average Purchase Frequency: 24.1
# Average Purchase Amount: 81705.79

# %%
print("""
Customer Segmentation Conclusion

1. Customers have been divided into groups using K-Means clustering.

2. Each segment shows unique purchasing behavior.

3. High-income and high-spending customers can be targeted for premium products.

4. Low-spending customers can be encouraged with discounts and loyalty programs.

5. Frequent buyers should receive personalized offers and membership benefits.

6. The segmentation helps businesses improve marketing strategies and customer retention.
""")
# Out:
# Customer Segmentation Conclusion
#
# 1. Customers have been divided into groups using K-Means clustering.
#
# 2. Each segment shows unique purchasing behavior.
#
# 3. High-income and high-spending customers can be targeted for premium products.
#
# 4. Low-spending customers can be encouraged with discounts and loyalty programs.
#
# 5. Frequent buyers should receive personalized offers and membership benefits.
#
# 6. The segmentation helps businesses improve marketing strategies and customer retention.
